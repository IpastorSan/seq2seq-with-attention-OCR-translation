# %% [markdown]
# <a href="https://colab.research.google.com/github/IpastorSan/seq2seq-with-attention-OCR-translation/blob/master/attention_seq2seq_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# #1)Relevant Imports

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import GRU, Input, Dense, Embedding, Bidirectional, Concatenate
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec, KeyedVectors
from nltk.translate.bleu_score import corpus_bleu
import pandas as pd
import matplotlib.pyplot as plt

# %%
######Data Preparation#######

def open_data(dataset, num_examples=None):
    with open(dataset) as archivo:
        datos = [line.rstrip('\n') for line in archivo]
        corpus = datos[:num_examples]

    return corpus


# Corpus. Adapt the path to your directory
num_examples = 20000
corpus_zh = open_data("/content/gdrive/My Drive/tfm/dataset_zh.txt", num_examples=num_examples)
corpus_en = open_data("/content/gdrive/My Drive/tfm/dataset_en.txt", num_examples=num_examples)

# %% [markdown]
# #2)Maximum length, Tokenizer, Pretrained, embeddings and batch generator

# %% [markdown]
# ##2.1)max len

# %%
def max_len(data):
    return max(len(line.split()) for line in data)

# Set max len
zh_max_len = max_len(corpus_zh)
en_max_len = max_len(corpus_en)
global_max_len = max(en_max_len, zh_max_len)  #This helps us when training the model, setting all lengths to the maximum

# %% [markdown]
# ##2.2 Tokenizer

# %%
def tokenizer(dataset, max_len, max_features, language="en"):
    tokenizer_lang = Tokenizer(num_words=max_features, filters="")

    tokenizer_lang.fit_on_texts(dataset)

    word_tensor = tokenizer_lang.texts_to_sequences(dataset)
    word_tensor = tf.keras.preprocessing.sequence.pad_sequences(word_tensor,maxlen=max_len, padding="post")

    return tokenizer_lang, word_tensor  #dictionary with tokenized words/sequences translated to numbers

# Tokenizacion. We obtain tokenizer and sequences
zh_tokenizer_lang, zh_word_tensor = tokenizer(corpus_zh, global_max_len, max_features=3000)
en_tokenizer_lang, en_word_tensor = tokenizer(corpus_en, global_max_len, max_features=3000)

# %%
# Length of each set of vocabulary
zh_vocab_size = len(zh_tokenizer_lang.word_index)
en_vocab_size = len(en_tokenizer_lang.word_index)

# %%
#Split the dataset into train and test sets
zh_train, zh_test, en_train, en_test = train_test_split(zh_word_tensor, en_word_tensor, test_size=0.1, random_state=13)

# %% [markdown]
# ##2.3 Embeddings

# %%
#Preparation of embedding files.
#Source Chinese Embedding: https://github.com/Kyubyong/wordvectors
#Source English Embedding: https://fasttext.cc/docs/en/english-vectors.html
#All embeddings come from word2vec models

embedding_file_en = "/content/gdrive/My Drive/tfm/en.bin"
embedding_file_zh = "/content/gdrive/My Drive/tfm/zh.bin"


def from_w2v_to_dict(embedding_file, lang="zh"):
    if lang == "en":
        model = KeyedVectors.load_word2vec_format(embedding_file, binary=True)
    else:
        model = Word2Vec.load(embedding_file)

    vector = model.wv.vectors
    words = model.wv.index2word
    union_embeddings = dict(zip(words, vector))
    return union_embeddings

# %%
embedding_zh = from_w2v_to_dict(embedding_file_zh)
embedding_en = from_w2v_to_dict(embedding_file_en, lang="en")
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
#Extract embedding weights to input into Keras Embedding Layer. Words not found in the embedding
#will be substitued with a random vector with normal distribution with mean=embedding mean and std=embedding std


def get_embedding_weights(embedd_dict, tokenizer_index, max_features=1000):
    embed = list(embedd_dict.values())

    all_embs = np.stack(embed)
    emb_mean, emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]  # probar

    word_index = tokenizer_index.word_index
    nb_words = len(word_index)

    embedding_matrix = np.random.normal(emb_mean, emb_std, \
                                        size=(nb_words, embed_size))

    for word, i in word_index.items():
        if i >= max_features:
            continue
        embedding_vector = np.array(embedd_dict.get(word))
        if embedding_vector.size is not 1:
            embedding_matrix[i] = embedding_vector

    return embedding_matrix

# %%
emb_zh = get_embedding_weights(embedding_zh, zh_tokenizer_lang, max_features=zh_vocab_size)
emb_en = emb = get_embedding_weights(embedding_en, en_tokenizer_lang, max_features=en_vocab_size)

# %% [markdown]
# ##2.4 Batch Generator

# %%
########Batch Generator for training. We also implement teacher forcing here######

def generate_batch(X, y, global_max_len, vocab_size_out, batch_size):
    while True:
        for j in range(0, len(X), batch_size):
            encoder_input_data = np.zeros((batch_size, global_max_len), dtype='float32')
            decoder_input_data = np.zeros((batch_size, global_max_len), dtype='float32')
            decoder_target_data = np.zeros((batch_size, global_max_len, vocab_size_out), dtype='float32')
            for i, (input_text, target_text) in enumerate(zip(X[j:j + batch_size], y[j:j + batch_size])):
                for t, word in enumerate(input_text):
                    encoder_input_data[i, t] = word  # encoder input seq
                for t, word in enumerate(target_text):
                    if t < len(target_text) - 1:
                        decoder_input_data[i, t] = word  # decoder input seq
                    if t > 0:
                        # decoder target sequence (one hot encoded)
                        # does not include the "start" token and is offset by one timestep
                        decoder_target_data[i, t - 1, word] = 1  # si el vector es (1, 2, 4) ese 4 es 0001
            yield ([encoder_input_data, decoder_input_data], decoder_target_data)

# %% [markdown]
# #3) Encoder-Decoder for training

# %%
###########Model for training. GRU units, Bidirectional, with Attention (Bahdanau)#########

#Bahdanau Attention (from Tensorflow Tutorial)

class BahdanauAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, query, values):
        # query hidden state shape == (batch_size, hidden size)
        # query_with_time_axis shape == (batch_size, 1, hidden size)
        # values shape == (batch_size, max_len, hidden size)
        # we are doing this to broadcast addition along the time axis to calculate the score
        query_with_time_axis = tf.expand_dims(query, 1)

        # score shape == (batch_size, max_length, 1)
        # we get 1 at the last axis because we are applying score to self.V
        # the shape of the tensor before applying self.V is (batch_size, max_length, units)
        score = self.V(tf.nn.tanh(
            self.W1(query_with_time_axis) + self.W2(values)))

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
#Model seq2seq

nodes = 1024
learning_rate = 0.001
clip_value = 1
dropout = 0.01

# encoder-Chinese
encoder_input = Input(shape=(global_max_len,))
#mask_zero=True allows for the padding 0 at the end of the sequence to be ignored
encoder_embedding = Embedding(zh_vocab_size, 300, input_length=global_max_len, mask_zero=True)(encoder_input)

encoder_output, state_h_f, state_h_b = Bidirectional(GRU(nodes, return_sequences=True,unroll=True,\
                                return_state=True,name="encoder_gru_2"))(encoder_embedding)

state_h = Concatenate(name="states_h")([state_h_f, state_h_b])

# Attention Layer
attention_layer = BahdanauAttention(nodes * 2)
context_vector, attention_weights = attention_layer(state_h, encoder_output)  # output del encoder y decoder
context_vector = tf.keras.layers.RepeatVector(global_max_len)(
    context_vector)  # repeat vector=length of target sequence

# decoder-English
decoder_input = Input(shape=(global_max_len), name="decoder_input")

decoder_emb = Embedding(en_vocab_size, 300, input_length=global_max_len,mask_zero=True)(decoder_input)

decoder_emb_attention = tf.concat([context_vector, decoder_emb], axis=-1)


decoder_output, _ = decoder_gru = GRU(nodes* 2, return_sequences=True, return_state=True,unroll=True,\
                  dropout=dropout,name="decoder_gru_1")(decoder_emb_attention, initial_state=state_h)

#Decoder Output
decoder_dense_output = Dense(en_vocab_size, activation="softmax")(decoder_output)

model = Model(inputs=[encoder_input, decoder_input], outputs=[decoder_dense_output])

# compile model
model.compile(optimizer=Adam(learning_rate=learning_rate, clipvalue=clip_value), metrics=["accuracy"],\
              loss="categorical_crossentropy")
# Summarize compiled model
model.summary()
plot_model(model, to_file="/content/gdrive/My Drive/tfm/model_2_1.png", show_shapes=True)
# Out:
# WARNING:tensorflow:Layer encoder_gru_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer encoder_gru_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer encoder_gru_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer decoder_gru_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "functional_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 17)]         0
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, 17, 300)      3168600     input_9[0][0]
# __________________________________________________________________________________________________
# bidirectional_16 (Bidirectional [(None, 17, 2048), ( 8146944     embedding_14[0][0]
# __________________________________________________________________________________________________
# states_h (Concatenate)          (None, 2048)         0           bidirectional_16[0][1]
#                                                                  bidirectional_16[0][2]
# __________________________________________________________________________________________________
# bahdanau_attention_6 (BahdanauA ((None, 2048), (None 8394753     states_h[0][0]
#                                                                  bidirectional_16[0][0]
# __________________________________________________________________________________________________
# decoder_input (InputLayer)      [(None, 17)]         0
# __________________________________________________________________________________________________
# repeat_vector_6 (RepeatVector)  (None, 17, 2048)     0           bahdanau_attention_6[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, 17, 300)      1614300     decoder_input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_6 (TensorFlo [(None, 17, 2348)]   0           repeat_vector_6[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# decoder_gru_1 (GRU)             [(None, 17, 2048), ( 27021312    tf_op_layer_concat_6[0][0]
#                                                                  states_h[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 17, 5381)     11025669    decoder_gru_1[0][0]
# ==================================================================================================
# Total params: 59,371,578
# Trainable params: 59,371,578
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# fit model
epochs = 100
b_size = 512
checkpoint = ModelCheckpoint("/content/gdrive/My Drive/tfm/model_weights_v1.h5", monitor="val_loss",\
                             verbose=1, save_best_only=True , mode="min", save_weights_only=True)
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=3)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=10)

history = model.fit(generate_batch(zh_train, en_train, global_max_len, en_vocab_size, b_size), \
          steps_per_epoch=len(zh_train) // b_size, \
          epochs=epochs, \
          validation_data=generate_batch(zh_test, en_test, global_max_len, en_vocab_size, b_size), \
          validation_steps=len(zh_test) // b_size, \
          verbose=1, \
          callbacks=[checkpoint, lr_scheduler, early_stopping], )

#model.save("/content/gdrive/My Drive/tfm/model_complete_v1.h5")
# Out:
# Epoch 1/100
# 35/35 [==============================] - ETA: 0s - loss: 3.6035 - accuracy: 0.5379
# Epoch 00001: val_loss improved from inf to 2.59331, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 65s 2s/step - loss: 3.6035 - accuracy: 0.5379 - val_loss: 2.5933 - val_accuracy: 0.5812
# Epoch 2/100
# 35/35 [==============================] - ETA: 0s - loss: 2.6078 - accuracy: 0.5776
# Epoch 00002: val_loss improved from 2.59331 to 2.31015, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 63s 2s/step - loss: 2.6078 - accuracy: 0.5776 - val_loss: 2.3101 - val_accuracy: 0.6277
# Epoch 3/100
# 35/35 [==============================] - ETA: 0s - loss: 2.0663 - accuracy: 0.6743
# Epoch 00003: val_loss improved from 2.31015 to 2.01916, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 63s 2s/step - loss: 2.0663 - accuracy: 0.6743 - val_loss: 2.0192 - val_accuracy: 0.6798
# Epoch 4/100
# 35/35 [==============================] - ETA: 0s - loss: 1.8669 - accuracy: 0.6967
# Epoch 00004: val_loss improved from 2.01916 to 1.85351, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 1.8669 - accuracy: 0.6967 - val_loss: 1.8535 - val_accuracy: 0.6992
# Epoch 5/100
# 35/35 [==============================] - ETA: 0s - loss: 1.7154 - accuracy: 0.7160
# Epoch 00005: val_loss improved from 1.85351 to 1.72944, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 1.7154 - accuracy: 0.7160 - val_loss: 1.7294 - val_accuracy: 0.7162
# Epoch 6/100
# 35/35 [==============================] - ETA: 0s - loss: 1.5565 - accuracy: 0.7343
# Epoch 00006: val_loss improved from 1.72944 to 1.59591, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 1.5565 - accuracy: 0.7343 - val_loss: 1.5959 - val_accuracy: 0.7293
# Epoch 7/100
# 35/35 [==============================] - ETA: 0s - loss: 1.4177 - accuracy: 0.7484
# Epoch 00007: val_loss improved from 1.59591 to 1.49686, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 1.4177 - accuracy: 0.7484 - val_loss: 1.4969 - val_accuracy: 0.7428
# Epoch 8/100
# 35/35 [==============================] - ETA: 0s - loss: 1.2967 - accuracy: 0.7601
# Epoch 00008: val_loss improved from 1.49686 to 1.42630, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 1.2967 - accuracy: 0.7601 - val_loss: 1.4263 - val_accuracy: 0.7516
# Epoch 9/100
# 35/35 [==============================] - ETA: 0s - loss: 1.1851 - accuracy: 0.7724
# Epoch 00009: val_loss improved from 1.42630 to 1.36759, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 1.1851 - accuracy: 0.7724 - val_loss: 1.3676 - val_accuracy: 0.7563
# Epoch 10/100
# 35/35 [==============================] - ETA: 0s - loss: 1.0777 - accuracy: 0.7855
# Epoch 00010: val_loss improved from 1.36759 to 1.30106, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 1.0777 - accuracy: 0.7855 - val_loss: 1.3011 - val_accuracy: 0.7697
# Epoch 11/100
# 35/35 [==============================] - ETA: 0s - loss: 0.9853 - accuracy: 0.7976
# Epoch 00011: val_loss improved from 1.30106 to 1.23550, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 0.9853 - accuracy: 0.7976 - val_loss: 1.2355 - val_accuracy: 0.7788
# Epoch 12/100
# 35/35 [==============================] - ETA: 0s - loss: 0.8717 - accuracy: 0.8144
# Epoch 00012: val_loss improved from 1.23550 to 1.19306, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 0.8717 - accuracy: 0.8144 - val_loss: 1.1931 - val_accuracy: 0.7870
# Epoch 13/100
# 35/35 [==============================] - ETA: 0s - loss: 0.7730 - accuracy: 0.8302
# Epoch 00013: val_loss improved from 1.19306 to 1.15530, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 0.7730 - accuracy: 0.8302 - val_loss: 1.1553 - val_accuracy: 0.7935
# Epoch 14/100
# 35/35 [==============================] - ETA: 0s - loss: 0.6834 - accuracy: 0.8462
# Epoch 00014: val_loss improved from 1.15530 to 1.13911, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 0.6834 - accuracy: 0.8462 - val_loss: 1.1391 - val_accuracy: 0.7985
# Epoch 15/100
# 35/35 [==============================] - ETA: 0s - loss: 0.6057 - accuracy: 0.8603
# Epoch 00015: val_loss improved from 1.13911 to 1.12756, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 0.6057 - accuracy: 0.8603 - val_loss: 1.1276 - val_accuracy: 0.8007
# Epoch 16/100
# 35/35 [==============================] - ETA: 0s - loss: 0.5311 - accuracy: 0.8762
# Epoch 00016: val_loss improved from 1.12756 to 1.12718, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 0.5311 - accuracy: 0.8762 - val_loss: 1.1272 - val_accuracy: 0.8026
# Epoch 17/100
# 35/35 [==============================] - ETA: 0s - loss: 0.4707 - accuracy: 0.8882
# Epoch 00017: val_loss improved from 1.12718 to 1.11021, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 0.4707 - accuracy: 0.8882 - val_loss: 1.1102 - val_accuracy: 0.8079
# Epoch 18/100
# 35/35 [==============================] - ETA: 0s - loss: 0.4001 - accuracy: 0.9040
# Epoch 00018: val_loss improved from 1.11021 to 1.11003, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 0.4001 - accuracy: 0.9040 - val_loss: 1.1100 - val_accuracy: 0.8084
# Epoch 19/100
# 35/35 [==============================] - ETA: 0s - loss: 0.3377 - accuracy: 0.9190
# Epoch 00019: val_loss did not improve from 1.11003
# 35/35 [==============================] - 63s 2s/step - loss: 0.3377 - accuracy: 0.9190 - val_loss: 1.1233 - val_accuracy: 0.8082
# Epoch 20/100
# 35/35 [==============================] - ETA: 0s - loss: 0.2834 - accuracy: 0.9322
# Epoch 00020: val_loss did not improve from 1.11003
# 35/35 [==============================] - 62s 2s/step - loss: 0.2834 - accuracy: 0.9322 - val_loss: 1.1274 - val_accuracy: 0.8095
# Epoch 21/100
# 35/35 [==============================] - ETA: 0s - loss: 0.2374 - accuracy: 0.9441
# Epoch 00021: val_loss did not improve from 1.11003
# 35/35 [==============================] - 62s 2s/step - loss: 0.2374 - accuracy: 0.9441 - val_loss: 1.1390 - val_accuracy: 0.8114
# Epoch 22/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9598
# Epoch 00022: val_loss improved from 1.11003 to 1.10334, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 64s 2s/step - loss: 0.1802 - accuracy: 0.9598 - val_loss: 1.1033 - val_accuracy: 0.8169
# Epoch 23/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1518 - accuracy: 0.9693
# Epoch 00023: val_loss improved from 1.10334 to 1.10332, saving model to /content/gdrive/My Drive/tfm/model_weights_v1.h5
# 35/35 [==============================] - 63s 2s/step - loss: 0.1518 - accuracy: 0.9693 - val_loss: 1.1033 - val_accuracy: 0.8179
# Epoch 24/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9717
# Epoch 00024: val_loss did not improve from 1.10332
# 35/35 [==============================] - 62s 2s/step - loss: 0.1439 - accuracy: 0.9717 - val_loss: 1.1058 - val_accuracy: 0.8183
# Epoch 25/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9734
# Epoch 00025: val_loss did not improve from 1.10332
# 35/35 [==============================] - 62s 2s/step - loss: 0.1373 - accuracy: 0.9734 - val_loss: 1.1085 - val_accuracy: 0.8185
# Epoch 26/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9758
# Epoch 00026: val_loss did not improve from 1.10332
# 35/35 [==============================] - 62s 2s/step - loss: 0.1302 - accuracy: 0.9758 - val_loss: 1.1089 - val_accuracy: 0.8185
# Epoch 27/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9759
# Epoch 00027: val_loss did not improve from 1.10332
# 35/35 [==============================] - 62s 2s/step - loss: 0.1299 - accuracy: 0.9759 - val_loss: 1.1092 - val_accuracy: 0.8186
# Epoch 28/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9761
# Epoch 00028: val_loss did not improve from 1.10332
# 35/35 [==============================] - 62s 2s/step - loss: 0.1295 - accuracy: 0.9761 - val_loss: 1.1095 - val_accuracy: 0.8186
# Epoch 29/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1282 - accuracy: 0.9764
# Epoch 00029: val_loss did not improve from 1.10332
# 35/35 [==============================] - 62s 2s/step - loss: 0.1282 - accuracy: 0.9764 - val_loss: 1.1095 - val_accuracy: 0.8185
# Epoch 30/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.9764
# Epoch 00030: val_loss did not improve from 1.10332
# 35/35 [==============================] - 62s 2s/step - loss: 0.1287 - accuracy: 0.9764 - val_loss: 1.1096 - val_accuracy: 0.8186
# Epoch 31/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9764
# Epoch 00031: val_loss did not improve from 1.10332
# 35/35 [==============================] - 62s 2s/step - loss: 0.1284 - accuracy: 0.9764 - val_loss: 1.1096 - val_accuracy: 0.8186
# Epoch 32/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1284 - accuracy: 0.9763
# Epoch 00032: val_loss did not improve from 1.10332
# 35/35 [==============================] - 62s 2s/step - loss: 0.1284 - accuracy: 0.9763 - val_loss: 1.1096 - val_accuracy: 0.8186
# Epoch 33/100
# 35/35 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9764
# Epoch 00033: val_loss did not improve from 1.10332
# 35/35 [==============================] - 62s 2s/step - loss: 0.1285 - accuracy: 0.9764 - val_loss: 1.1096 - val_accuracy: 0.8186
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-44-9ea4ea52f81f> in <module>()
#       8 history = model.fit(generate_batch(zh_train, en_train, global_max_len, en_vocab_size, b_size),           steps_per_epoch=len(zh_train) // b_size,           epochs=epochs,           validation_data=generate_batch(zh_test, en_test, global_max_len, en_vocab_size, b_size),           validation_steps=len(zh_test) // b_size,           verbose=1,           callbacks=[checkpoint, lr_scheduler, early_stopping], )
#       9
# ---> 10 model.save("/content/gdrive/My Drive/tfm/model_complete_v1.h5")
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options)
#    1977     """
#    1978     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
# -> 1979                     signatures, options)
#    1980
#    1981   def save_weights(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options)
#     129           'or using `save_weights`.')
#     130     hdf5_format.save_model_to_hdf5(
# --> 131         model, filepath, overwrite, include_optimizer)
#     132   else:
#     133     saved_model_save.save(model, filepath, overwrite, include_optimizer,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     107
#     108   try:
# --> 109     model_metadata = saving_utils.model_metadata(model, include_optimizer)
#     110     for k, v in model_metadata.items():
#     111       if isinstance(v, (dict, list, tuple)):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/saving_utils.py in model_metadata(model, include_optimizer, require_config)
#     155   except NotImplementedError as e:
#     156     if require_config:
# --> 157       raise e
#     158
#     159   metadata = dict(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/saving_utils.py in model_metadata(model, include_optimizer, require_config)
#     152   model_config = {'class_name': model.__class__.__name__}
#     153   try:
# --> 154     model_config['config'] = model.get_config()
#     155   except NotImplementedError as e:
#     156     if require_config:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/functional.py in get_config(self)
#     596
#     597   def get_config(self):
# --> 598     return copy.deepcopy(get_network_config(self))
#     599
#     600   @classmethod
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/functional.py in get_network_config(network, serialize_layer_fn)
#    1276         filtered_inbound_nodes.append(node_data)
#    1277
# -> 1278     layer_config = serialize_layer_fn(layer)
#    1279     layer_config['name'] = layer.name
#    1280     layer_config['inbound_nodes'] = filtered_inbound_nodes
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/generic_utils.py in serialize_keras_object(instance)
#     248         return serialize_keras_class_and_config(
#     249             name, {_LAYER_UNDEFINED_CONFIG_KEY: True})
# --> 250       raise e
#     251     serialization_config = {}
#     252     for key, item in config.items():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/generic_utils.py in serialize_keras_object(instance)
#     243     name = get_registered_name(instance.__class__)
#     244     try:
# --> 245       config = instance.get_config()
#     246     except NotImplementedError as e:
#     247       if _SKIP_FAILED_SERIALIZATION:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py in get_config(self)
#     676       raise NotImplementedError('Layer %s has arguments in `__init__` and '
#     677                                 'therefore must override `get_config`.' %
# --> 678                                 self.__class__.__name__)
#     679     return config
#     680
#
# NotImplementedError: Layer BahdanauAttention has arguments in `__init__` and therefore must override `get_config`.

# %%
#get all the data and plot it
#history.history dictionary containing loss and any extra metrics 
#history.params training parameters
#history.epoch list of epochs
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.show()

# %% [markdown]
# #4) Encoder-Decoder for inference

# %%
##############Model modified for INFERENCE##################

# encoder_model_inference is the same
encoder_inf = Model(encoder_input, [encoder_output, state_h])

#encoder_inf.save("/content/gdrive/My Drive/tfm/encoder_inf_model_v3_1.h5")
encoder_inf.save_weights("/content/gdrive/My Drive/tfm/encoder_inf_weights_v3_1.h5")


#decoder_model_inference 1
decoder_inf_state_input_h = Input(shape=(nodes*2,), name="encoder_hidden_state")
encoder_output_input = Input(shape=(global_max_len, nodes*2))

#decoder_inputs
decoder_inf_input = Input(shape=(1,))
decoder_inf_input_one = Embedding(en_vocab_size, 300,\
                        weights=[emb_en],mask_zero=True)(decoder_inf_input)

#Attention Layer
attention_layer = BahdanauAttention(nodes*2)
context_vector, attention_weights = attention_layer(decoder_inf_state_input_h, encoder_output_input)#output del encoder y decoder
context_vector = tf.keras.layers.RepeatVector(1)(context_vector)#repeat vector=longitud de secuencia objetivo 

#decoder
decoder_emb_attention = tf.concat([context_vector, decoder_inf_input_one], axis=-1)

decoder_output_inf, h_inf = GRU(nodes* 2, return_sequences=True, return_state=True,unroll=True,\
                  dropout=dropout,name="decoder_gru_2")(decoder_emb_attention,\
                                                        initial_state=decoder_inf_state_input_h)

decoder_inf_state = h_inf

#Decoder Output

decoder_inf_output = Dense(en_vocab_size, activation="softmax")(decoder_output_inf)


decoder_inf_model = Model([decoder_inf_input, encoder_output_input, decoder_inf_state_input_h],\
                          [decoder_inf_output, decoder_inf_state])
decoder_inf_model.summary()

plot_model(decoder_inf_model, to_file="/content/gdrive/My Drive/tfm/decoder_inf_model_v2.png",\
           show_shapes=True, show_layer_names =True)
# Out:
# WARNING:tensorflow:Layer decoder_gru_2 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "functional_23"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_hidden_state (InputLaye [(None, 2048)]       0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           [(None, 17, 2048)]   0
# __________________________________________________________________________________________________
# bahdanau_attention_10 (Bahdanau ((None, 2048), (None 8394753     encoder_hidden_state[0][0]
#                                                                  input_18[0][0]
# __________________________________________________________________________________________________
# input_19 (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# repeat_vector_10 (RepeatVector) (None, 1, 2048)      0           bahdanau_attention_10[0][0]
# __________________________________________________________________________________________________
# embedding_20 (Embedding)        (None, 1, 300)       1614300     input_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_10 (TensorFl [(None, 1, 2348)]    0           repeat_vector_10[0][0]
#                                                                  embedding_20[0][0]
# __________________________________________________________________________________________________
# decoder_gru_2 (GRU)             [(None, 1, 2048), (N 27021312    tf_op_layer_concat_10[0][0]
#                                                                  encoder_hidden_state[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 1, 5381)      11025669    decoder_gru_2[0][0]
# ==================================================================================================
# Total params: 48,056,034
# Trainable params: 48,056,034
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #5 Inference Loop

# %%
#Reverse dictionary integer-word

decoding_dict = {v: k for k, v in en_tokenizer_lang.word_index.items()}

decode_zh = {v: k for k, v in zh_tokenizer_lang.word_index.items()}
decode_en = {v: k for k, v in en_tokenizer_lang.word_index.items()}

# %%
def translate_sentence(input_sentence, target_tokenizer, decoding_dict, output_max_len):
    encoder_output, states_value = encoder_inf.predict(input_sentence)

    target_sequence = np.zeros((1, 1))
    target_sequence[0, 0] = target_tokenizer.word_index.get("start")
    end_of_sequence = target_tokenizer.word_index.get("end")

    translated_sentence = []

    for i in range(output_max_len):
        output_token, decoder_states = decoder_inf_model.predict([target_sequence,encoder_output, states_value])
        id_word = np.argmax(output_token[0, -1, :])

        if id_word == end_of_sequence or input_sentence[0][i] == 0:  #this is wrong so far
            break

        decoded_word = ""

        if id_word > 0:
            decoded_word = decoding_dict[id_word]
            translated_sentence.append(decoded_word)

        target_sequence[0, 0] = id_word
        states_value = decoder_states

    return " ".join(translated_sentence)

# %%
src= zh_test[0:1]
zh_tokenizer_lang.sequences_to_texts(src)
# Out:
# ['他 昨天 來 看 你 。']

# %%
tr = translate_sentence(src, en_tokenizer_lang, decode_en, global_max_len)
tr
# Out:
# 'massage complex patience dependent dependent book'

# %% [markdown]
# #6) Evaluate model

# %%
def translate_corpus(corpus, tokenizer, decoding_dict, output_max_len):
    corpus_list = list()
    for i in range(0, len(corpus)):
        line = translate_sentence(corpus[i:i + 1], tokenizer, decoding_dict, output_max_len)
        corpus_list.append(line)
    return corpus_list

# %%
#######Model Evaluation######3
decode_zh = {v: k for k, v in zh_tokenizer_lang.word_index.items()}
decode_en = {v: k for k, v in en_tokenizer_lang.word_index.items()}

decode_zh.update({0: "0"})
decode_en.update({0: "0"})

# %%
def decode_source(sentence):
    sent = np.ndarray.tolist(sentence)
    words = [decode_zh.get(letter) for letter in sent]
    my_texts = (["".join(words[i]) for i in range(len(words))])
    text = [i for i in my_texts if i != "0"]
    return text


def decode_target(sentence):
    sent = np.ndarray.tolist(sentence)
    words = [decode_en.get(letter) for letter in sent]
    my_texts = (["".join(words[i]) for i in range(len(words))])
    text = [i for i in my_texts if i != "0"]
    return text

# %%
# tokenizer = en_tokenizer_lang
# output_max_len = global_max_len
# decoding_dict = decode_zh
def evaluate_model(source_corpus, target_corpus):
    original = source_corpus   #format: list of sentences as words
    actual = [decode_target(target_corpus[i]) for i in
              range(len(target_corpus))] #format: list of sentence as tokens
    predicted = translate_corpus(source_corpus, en_tokenizer_lang, \
                                 decoding_dict=decode_en, output_max_len=global_max_len)

    print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
    print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
    print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
    print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# %%
c = zh_test[0:1000]
p = en_test[0:1000]
evaluacion = evaluate_model(c, p)
# Out:
# BLEU-1: 0.248611
# BLEU-2: 0.123537
# BLEU-3: 0.066228
# BLEU-4: 0.021898
